# %% [markdown]
# #[Tutorial Point](https://www.tutorialspoint.com/statistics/best_point_estimation.htm)
#
# ##Best Point Estimation
# - Maximum Likelihood Estimation
# - Laplace (via shift)
# - Jeffery (via shift)
# - Wilson (via z score)
