# %% [markdown]
# [TensorFLow2.0 Tut](https://www.udemy.com/course/tensorflow-2-practical/)

# %% [markdown]
# [AI2 Course](https://drive.google.com/drive/folders/1qG6wyTqLdBdKBQimxNwcwu3cdXI9QrZj)

# %% [markdown]
# Math tutorial: https://course.fast.ai/
#
# ##Bayesian network package python
#
# – python wrapper to a C++ graphical library
#
# https://agrum.gitlab.io/pages/pyagrum-installation.html
#
# Bayes MAP Classifier
# https://www.kdnuggets.com/2019/04/naive-bayes-baseline-model-machine-learning-classification-performance.html/2
#
# Create a decision tree
#
# Question on test: take initial probability graph and create summation probability tree
# -	Sampling from the joint distribution
# -	Variable elimination algorithms
#
# Backpropegation neural network w/o tensor flow
# ##Gaussian naïve bayes Number classifier
# https://scipy-lectures.org/packages/scikit-learn/auto_examples/plot_digits_simple_classif.html
#
# https://dev.to/shamdasani/build-a-flexible-neural-network-with-backpropagation-in-python
# ##Neural Network
# https://www.guru99.com/artificial-neural-network-tutorial.html
# https://victorzhou.com/blog/intro-to-neural-networks/
# https://www.bayesserver.com/code/python/decision-graphs-py
# ##Activation Function
# https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0
# ##Pytorch
# https://pytorch.org/get-started/locally/#anaconda
# ##Pytorch tutorial
# https://pytorch.org/tutorials/intermediate/tensorboard_tutorial.html
# ##Pytorch and tensorboard in colab
# https://medium.com/looka-engineering/how-to-use-tensorboard-with-pytorch-in-google-colab-1f76a938bc34
# ##Path setting python and conda
# https://medium.com/@GalarnykMichael/install-python-on-windows-anaconda-c63c7c3d1444
# ##tensorboard tutorial
# ##Tensorboard setup in browser
# 1.	Run script and save writer to some directory
# 2.	Open CMD and navigate to DIRECTORY WHERE SCRIPT IS LOCATED
# 3.	Run >tensorboard –logdir=(log directory name here) –host=localhost –port=8888
#
#
#
# https://www.datacamp.com/community/tutorials/tensorboard-tutorial
# ##LTSM and RNN
# https://adventuresinmachinelearning.com/keras-lstm-tutorial/
# ##Matrix dimensions for network
# https://medium.com/from-the-scratch/deep-learning-deep-guide-for-all-your-matrix-dimensions-and-calculations-415012de1568
# ##Useful information
# https://github.com/Createdd/Writing/blob/master/2018/articles/DebugTFBasics.md#1-fetch-and-print-values-within-sessionrun
# ##Stock market prediction using tensor flow
# https://medium.com/mlreview/a-simple-deep-learning-model-for-stock-price-prediction-using-tensorflow-30505541d877
# ##KNN
# Math: https://people.revoledu.com/kardi/tutorial/KNN/KNN_Numerical-example.html
# ##Regression
# https://www.geeksforgeeks.org/regression-classification-supervised-machine-learning/
# ##Support Vector Machine
# https://www.datacamp.com/community/tutorials/svm-classification-scikit-learn-python
